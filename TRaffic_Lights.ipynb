# %% [markdown]
# <a href="https://colab.research.google.com/github/NNL-Keerthana/WebOps_Blockchain/blob/main/TRaffic_Lights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.4/799.4 kB 6.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# Just test example

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 106.1ms
# Speed: 3.2ms preprocess, 106.1ms inference, 540.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.predict(
   source='https://media.roboflow.com/notebooks/examples/dog.jpeg',
   conf=0.25
)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 25.0MB/s]
# ...
# 100%|██████████| 104k/104k [00:00<00:00, 49.0MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 93.6ms
# Speed: 13.2ms preprocess, 93.6ms inference, 746.5ms postprocess per image at shape (1, 3, 640, 384)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %% [markdown]
# Load Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Y5kKQ6Tle9XaD1NjfxgK")
project = rf.workspace("traffic-light-detection-qsrxn").project("traffic-light-oq7uj")
version = project.version(25)
dataset = version.download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-light-25 in yolov5pytorch:: 100%|██████████| 5064/5064 [00:00<00:00, 6400.45it/s]

# %% [markdown]
# ### Train
# model: Yolov8
#
# 100 epochs
#
# preprocessed in Roboflow. (size set to 640x640 with autoscale)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100
imgsz=640
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
version.deploy("yolov8", model_path="/content/runs/detect/train5/weights") # provide path to directory containing the model

# %% [markdown]
# Validate Model

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train5/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/traffic-light-25/valid/labels.cache... 495 images, 0 backgrounds, 0 corrupt: 100% 495/495 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:10<00:00,  2.96it/s]
#                    all        495        695      0.967      0.952      0.979      0.815
#                  green         86        116      0.952      0.974      0.983      0.862
#                    red        357        512       0.98      0.971      0.989      0.808
#                 yellow         57         67      0.968      0.912      0.967      0.775
# Speed: 1.0ms preprocess, 9.4ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Test Model

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt conf=0.25 source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/264 /content/traffic-light-25/test/images/IMG_1481_jpg.rf.e3665dff27554a16746332d922358ea0.jpg: 640x640 2 yellows, 16.5ms
# image 2/264 /content/traffic-light-25/test/images/IMG_1501_jpg.rf.eb9dc1138e330608efde83e7fa586fcc.jpg: 640x640 2 yellows, 16.4ms
# image 3/264 /content/traffic-light-25/test/images/IMG_1554_JPG.rf.b936acf487a26425093895539aa431f7.jpg: 640x640 3 yellows, 16.4ms
# image 4/264 /content/traffic-light-25/test/images/IMG_8457_jpeg.rf.030f8b8ab39e9ca035d4e89bb090fc66.jpg: 640x640 2 reds, 16.3ms
# image 5/264 /content/traffic-light-25/test/images/predictions_jpg.rf.b8f5dc847a319f43f963d48b4f20d32e.jpg: 640x640 3 reds, 16.4ms
# image 6/264 /content/traffic-light-25/test/images/traffic-light-101-_jpg.rf.d0f9c1a11e9da455868d09c4066ff480.jpg: 640x640 1 yellow, 16.3ms
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Y5kKQ6Tle9XaD1NjfxgK")
project = rf.workspace("cdd-tnenr").project("traffic-light-detection-lcway")
version = project.version(1)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
version.deploy("yolov8", model_path="/content/runs/detect/train5")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.50, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.
